# %%
import pandas as pd

df = pd.read_csv("sis_summary_results.csv")

import matplotlib.pyplot as plt
# Plot
plt.figure(figsize=(8, 5))
plt.plot(df['m'], df['SteadyState'], marker='o', linestyle='-', color='black')
plt.xlabel('m (Average Degree or Link Count)')
plt.ylabel('Steady State Infection')
plt.title('Steady State Infection vs. m')
plt.grid(True)
plt.tight_layout()
plt.show()

# df[['m', 'SteadyState']]
df
# Out:
#     Network   m  beta  mu  SteadyState  steady_index:
# 0   WS-1000   0  0.21   1       0.0000              6
# 1   WS-1000   1  0.21   1       0.0000              7
# 2   WS-1000   2  0.21   1       0.0000             10
# 3   WS-1000   3  0.21   1       0.0000             14
# 4   WS-1000   4  0.21   1       0.0001             24
# 5   WS-1000   5  0.21   1       0.0021             48
# 6   WS-1000   6  0.21   1       0.0000            483
# 7   WS-1000   7  0.21   1       0.0667              4
# 8   WS-1000   8  0.21   1       0.0953             14
# 9   WS-1000   9  0.21   1       0.1183             16
# 10  WS-1000  10  0.21   1       0.1376             15
# 11  WS-1000  11  0.21   1       0.1545             13
# 12  WS-1000  12  0.21   1       0.1701             12
# 13  WS-1000  13  0.21   1       0.1833             11
# 14  WS-1000  14  0.21   1       0.1943             10
# 15  WS-1000  15  0.21   1       0.2059             10
# ...
