# %%
import pandas as pd

df = pd.read_csv("sis_summary_results.csv")

import matplotlib.pyplot as plt
# Plot
plt.figure(figsize=(8, 5))
plt.plot(df['m'], df['SteadyState'], marker='o', linestyle='-', color='black')
plt.xlabel('m (Average Degree or Link Count)')
plt.ylabel('Steady State Infection')
plt.title('Steady State Infection vs. m')
plt.grid(True)
plt.tight_layout()
plt.show()

# df[['m', 'SteadyState']]
df
# Out:
#     Network   m   beta  mu  SteadyState  steady_index:
# 0   BA-1000   0  0.115   1       0.0010             27
# 1   BA-1000   1  0.115   1       0.0016             33
# 2   BA-1000   2  0.115   1       0.0022             39
# 3   BA-1000   3  0.115   1       0.0030             47
# 4   BA-1000   4  0.115   1       0.0043             55
# 5   BA-1000   5  0.115   1       0.0000            111
# 6   BA-1000   6  0.115   1       0.0000            150
# 7   BA-1000   7  0.115   1       0.0000            202
# 8   BA-1000   8  0.115   1       0.0000            300
# 9   BA-1000   9  0.115   1       0.0000            433
# 10  BA-1000  10  0.115   1       0.0000            100
# 11  BA-1000  11  0.115   1       0.0000            100
# 12  BA-1000  12  0.115   1       0.0000            100
# 13  BA-1000  13  0.115   1       0.0432              0
# 14  BA-1000  14  0.115   1       0.0485              1
# 15  BA-1000  15  0.115   1       0.0530              3
# 16  BA-1000  16  0.115   1       0.0588              5
# 17  BA-1000  17  0.115   1       0.0638              5
# 18  BA-1000  18  0.115   1       0.0686              6
# 19  BA-1000  19  0.115   1       0.0733              6
# 20  BA-1000  20  0.115   1       0.0781              7
