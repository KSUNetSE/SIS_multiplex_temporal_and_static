# %%
import pandas as pd

df = pd.read_csv("sis_summary_results.csv")

import matplotlib.pyplot as plt
# Plot
plt.figure(figsize=(8, 5))
plt.plot(df['activity'], df['SteadyState'], marker='.', linestyle='--', color='black')
plt.xlabel('activity rate')
plt.ylabel('Steady State Infection')
plt.title('Steady State Infection vs. activity rate')
plt.grid(True)
plt.tight_layout()
plt.show()

# df[['m', 'SteadyState']]
df
# Out:
#     Network  activity  m  beta  mu  SteadyState  steady_index:
# 0   BA-1000     0.000  5  0.13   1       0.0000            485
# 1   BA-1000     0.005  5  0.13   1       0.0000            499
# 2   BA-1000     0.010  5  0.13   1       0.0000            100
# 3   BA-1000     0.015  5  0.13   1       0.0000            100
# 4   BA-1000     0.020  5  0.13   1       0.0000            100
# 5   BA-1000     0.025  5  0.13   1       0.0000            100
# 6   BA-1000     0.030  5  0.13   1       0.0000            100
# 7   BA-1000     0.035  5  0.13   1       0.0000            100
# 8   BA-1000     0.040  5  0.13   1       0.0000            100
# 9   BA-1000     0.045  5  0.13   1       0.0000            100
# 10  BA-1000     0.050  5  0.13   1       0.0000            100
# 11  BA-1000     0.055  5  0.13   1       0.0000            100
# 12  BA-1000     0.060  5  0.13   1       0.0325              0
# 13  BA-1000     0.065  5  0.13   1       0.0331              0
# ...

# %%
import pandas as pd

df = pd.read_csv("sis_summary_results.csv")

import matplotlib.pyplot as plt
# Plot
plt.figure(figsize=(8, 5))
plt.plot(df['activity'], df['SteadyState'], marker='.', linestyle='--', color='black')
plt.xlabel('activity rate')
plt.ylabel('Steady State Infection')
plt.title('Steady State Infection vs. activity rate')
plt.grid(True)
plt.tight_layout()
plt.show()

# df[['m', 'SteadyState']]
df
# Out:
#     Network  activity  m   beta  mu  SteadyState  steady_index:
# 0   BA-1000     0.000  5  0.125   1       0.0000            159
# 1   BA-1000     0.005  5  0.125   1       0.0000            168
# 2   BA-1000     0.010  5  0.125   1       0.0116             44
# 3   BA-1000     0.015  5  0.125   1       0.0000            200
# 4   BA-1000     0.020  5  0.125   1       0.0000            232
# 5   BA-1000     0.025  5  0.125   1       0.0000            253
# 6   BA-1000     0.030  5  0.125   1       0.0000            287
# 7   BA-1000     0.035  5  0.125   1       0.0000            100
# 8   BA-1000     0.040  5  0.125   1       0.0000            100
# 9   BA-1000     0.045  5  0.125   1       0.0000            100
# 10  BA-1000     0.050  5  0.125   1       0.0201              0
# 11  BA-1000     0.055  5  0.125   1       0.0000            100
# 12  BA-1000     0.060  5  0.125   1       0.0214              0
# 13  BA-1000     0.065  5  0.125   1       0.0000            100
# ...

# %%
import pandas as pd

df = pd.read_csv("sis_summary_results.csv")

import matplotlib.pyplot as plt
# Plot
plt.figure(figsize=(8, 5))
plt.plot(df['activity'], df['SteadyState'], marker='.', linestyle='--', color='black')
plt.xlabel('activity rate')
plt.ylabel('Steady State Infection')
plt.title('Steady State Infection vs. activity rate')
plt.grid(True)
plt.tight_layout()
plt.show()

# df[['m', 'SteadyState']]
df
# Out:
#     Network  activity  m  beta  mu  SteadyState  steady_index:
# 0   BA-1000     0.000  5  0.12   1       0.0041             48
# 1   BA-1000     0.005  5  0.12   1       0.0036             51
# 2   BA-1000     0.010  5  0.12   1       0.0045             46
# 3   BA-1000     0.015  5  0.12   1       0.0048             60
# 4   BA-1000     0.020  5  0.12   1       0.0053             51
# 5   BA-1000     0.025  5  0.12   1       0.0051             51
# 6   BA-1000     0.030  5  0.12   1       0.0069             58
# 7   BA-1000     0.035  5  0.12   1       0.0065             51
# 8   BA-1000     0.040  5  0.12   1       0.0071             48
# 9   BA-1000     0.045  5  0.12   1       0.0000            137
# 10  BA-1000     0.050  5  0.12   1       0.0000            126
# 11  BA-1000     0.055  5  0.12   1       0.0000            145
# 12  BA-1000     0.060  5  0.12   1       0.0000            147
# 13  BA-1000     0.065  5  0.12   1       0.0000            189
# ...

# %%
import pandas as pd

df = pd.read_csv("sis_summary_results.csv")

import matplotlib.pyplot as plt
# Plot
plt.figure(figsize=(8, 5))
plt.plot(df['activity'], df['SteadyState'], marker='.', linestyle='--', color='black')
plt.xlabel('activity rate')
plt.ylabel('Steady State Infection')
plt.title('Steady State Infection vs. activity rate')
plt.grid(True)
plt.tight_layout()
plt.show()

# df[['m', 'SteadyState']]
df
# Out:
#     Network  activity  m  beta  mu  SteadyState  steady_index:
# 0   BA-1000     0.000  5  0.13   1       0.0208              0
# 1   BA-1000     0.005  5  0.13   1       0.0219              0
# 2   BA-1000     0.010  5  0.13   1       0.0230              0
# 3   BA-1000     0.015  5  0.13   1       0.0219              0
# 4   BA-1000     0.020  5  0.13   1       0.0271              0
# 5   BA-1000     0.025  5  0.13   1       0.0289              0
# 6   BA-1000     0.030  5  0.13   1       0.0273              0
# 7   BA-1000     0.035  5  0.13   1       0.0288              0
# 8   BA-1000     0.040  5  0.13   1       0.0304              0
# 9   BA-1000     0.045  5  0.13   1       0.0312              0
# 10  BA-1000     0.050  5  0.13   1       0.0337              0
# 11  BA-1000     0.055  5  0.13   1       0.0342              0
# 12  BA-1000     0.060  5  0.13   1       0.0336              0
# 13  BA-1000     0.065  5  0.13   1       0.0375              0
# ...
