# %%
import pandas as pd

df = pd.read_csv("sis_summary_results.csv")

import matplotlib.pyplot as plt
# Plot
plt.figure(figsize=(8, 5))
plt.plot(df['activity'], df['SteadyState'], marker='.', linestyle='--', color='black')
plt.xlabel('activity rate')
plt.ylabel('Steady State Infection')
plt.title('Steady State Infection vs. activity rate')
plt.grid(True)
plt.tight_layout()
plt.show()

# df[['m', 'SteadyState']]
df
# Out:
#     Network  activity  m  beta  mu  SteadyState  steady_index:
# 0   ER-1000     0.000  5  0.09   1       0.0004             29
# 1   ER-1000     0.005  5  0.09   1       0.0003             30
# 2   ER-1000     0.010  5  0.09   1       0.0010             29
# 3   ER-1000     0.015  5  0.09   1       0.0004             36
# 4   ER-1000     0.020  5  0.09   1       0.0020             36
# 5   ER-1000     0.025  5  0.09   1       0.0013             44
# 6   ER-1000     0.030  5  0.09   1       0.0016             45
# 7   ER-1000     0.035  5  0.09   1       0.0022             53
# 8   ER-1000     0.040  5  0.09   1       0.0025             51
# 9   ER-1000     0.045  5  0.09   1       0.0032             46
# 10  ER-1000     0.050  5  0.09   1       0.0048             59
# 11  ER-1000     0.055  5  0.09   1       0.0000            105
# 12  ER-1000     0.060  5  0.09   1       0.0055             65
# 13  ER-1000     0.065  5  0.09   1       0.0000            131
# 14  ER-1000     0.070  5  0.09   1       0.0000            156
# 15  ER-1000     0.075  5  0.09   1       0.0000            207
# 16  ER-1000     0.080  5  0.09   1       0.0000            232
# 17  ER-1000     0.085  5  0.09   1       0.0000            100
# 18  ER-1000     0.090  5  0.09   1       0.0000            100
# 19  ER-1000     0.095  5  0.09   1       0.0245             38
# 20  ER-1000     0.100  5  0.09   1       0.0285            100
# 21  ER-1000     0.105  5  0.09   1       0.0317             29
# 22  ER-1000     0.110  5  0.09   1       0.0373              0
# 23  ER-1000     0.115  5  0.09   1       0.0387              0
# 24  ER-1000     0.120  5  0.09   1       0.0443              0
# 25  ER-1000     0.125  5  0.09   1       0.0473              0
# 26  ER-1000     0.130  5  0.09   1       0.0506              0
# 27  ER-1000     0.135  5  0.09   1       0.0534              0
# 28  ER-1000     0.140  5  0.09   1       0.0580              2
# 29  ER-1000     0.145  5  0.09   1       0.0593              2
# 30  ER-1000     0.150  5  0.09   1       0.0630              5
# 31  ER-1000     0.155  5  0.09   1       0.0644              5
# 32  ER-1000     0.160  5  0.09   1       0.0677              6
# 33  ER-1000     0.165  5  0.09   1       0.0712              8
# 34  ER-1000     0.170  5  0.09   1       0.0734              8
# 35  ER-1000     0.175  5  0.09   1       0.0746              8
# 36  ER-1000     0.180  5  0.09   1       0.0778             12
# 37  ER-1000     0.185  5  0.09   1       0.0806             13
# 38  ER-1000     0.190  5  0.09   1       0.0836             13
# 39  ER-1000     0.195  5  0.09   1       0.0842             13
# 40  ER-1000     0.200  5  0.09   1       0.0859             14
